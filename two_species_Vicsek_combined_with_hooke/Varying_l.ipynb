# %%
import File_for_accesing_src
from Standard_parameters import *
from Vicsek_hooke import *
import numpy as np
import matplotlib.pyplot as plt
from Quiver import *
from tqdm import tqdm

# %%
#Generate data
l_list=np.linspace(0,5,10)
pos_for_different_l=np.zeros([len(l_list),iterations,N,2 ])
theta_for_different_l=np.zeros([len(l_list),iterations,N ])
for n, l in tqdm(enumerate(l_list)):
    pos,theta=Vicsek_hooke(v_0,eta,r, N,L,iterations,s,k,l)
    pos_for_different_l[n]=pos
    theta_for_different_l[n]=theta
np.save("Data/pos_with_different_l" ,pos_for_different_l)
np.save("Data/theta_with_different_l" ,theta_for_different_l)
# Out:
# 10it [1:21:30, 489.05s/it]

# %%
#Load data
pos_for_different_l=np.load("Data/pos_with_different_l.npy")
theta_for_different_l=np.load("Data/theta_with_different_l.npy")
l_list=np.linspace(0,5,10)

# %%
from Animate_c import *

#Storing every animation 


for n, l in enumerate(l_list):
        anim=Animate_c(pos_for_different_l[n],theta_for_different_l[n],['blue','red'], [0.5,0.5], 1000,50)
        anim.save("Animations/varying_l_0_to_5/animation_l="+str(l)+".gif")
        plt.close()

# %%
from Animate_c import *
# %matplotlib qt
i=7
Animate_c(pos_for_different_l[i],theta_for_different_l[i],['blue','red'],[0.5,0.5],1000,100)

# %%
# %matplotlib inline
l_index=8
Quiver(pos_for_different_l[l_index][-100], theta_for_different_l[l_index][-100],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
#plt.savefig("Plots/Varying_l/quiver_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=1
Quiver(pos_for_different_l[l_index][-1], theta_for_different_l[l_index][-1],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("Plots/Varying_l/quiver_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=1
Quiver(pos_for_different_l[l_index][-1], theta_for_different_l[l_index][-1],['blue','red'])
plt.xlabel('x')
plt.xlim(24,26)
plt.ylim(7,9)
plt.ylabel('y')
plt.savefig("Plots/Varying_l/quiver_zoomed_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=6
Quiver(pos_for_different_l[l_index][900], theta_for_different_l[l_index][900],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("Plots/Varying_l/iteration_900_quiver_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=6
Quiver(pos_for_different_l[l_index][950], theta_for_different_l[l_index][950],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("Plots/Varying_l/iteration_950_quiver_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=6
Quiver(pos_for_different_l[l_index][-1], theta_for_different_l[l_index][-1],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.ylim(5,17.5)
plt.xlim(10,22.5)
plt.savefig("Plots/Varying_l/quiver_zoomed_l="+str(l_list[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=7
Quiver(pos_for_different_l[l_index][900], theta_for_different_l[l_index][900],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("Plots/varying_l/iteration_900_l="+  str(l_list[l_index])+ "_.pdf")
plt.show()

# %%
# %matplotlib inline
l_index=7
Quiver(pos_for_different_l[l_index][950], theta_for_different_l[l_index][950],['blue','red'])
plt.xlabel('x')
plt.ylabel('y')
plt.savefig("Plots/varying_l/iteration_950_l="+  str(l_list[l_index])+ "_.pdf")
plt.show()

# %% [markdown]
# Now trying with l in different range. Such that cluster alaways consit of blu and red part

# %%
#Generate data
l_list2=np.linspace(0.6,3,10)
pos_for_different_l2=np.zeros([len(l_list2),iterations,N,2 ])
theta_for_different_l2=np.zeros([len(l_list2),iterations,N ])
for n, l in tqdm(enumerate(l_list2)):
    pos,theta=Vicsek_hooke(v_0,eta,r, N,L,iterations,s,k,l)
    pos_for_different_l2[n]=pos
    theta_for_different_l2[n]=theta
np.save("Data/pos_with_different_l2" ,pos_for_different_l2)
np.save("Data/theta_with_different_l2" ,theta_for_different_l2)
# Out:
# 10it [2:53:17, 1039.77s/it]

# %%
#Load data
pos_for_different_l2=np.load("Data/pos_with_different_l2.npy")
theta_for_different_l2=np.load("Data/theta_with_different_l2.npy")
l_list2=np.linspace(0.6,3,10)

# %%
from Animate_c import *

#Storing every animation 


for n, l in enumerate(l_list2):
        anim=Animate_c(pos_for_different_l2[n],theta_for_different_l2[n],['blue','red'], [0.5,0.5], 1000,50)
        anim.save("Animations/varying_l_0_6_to_3/animation_l="+str(l)+".gif")
        plt.close()

# %%
from Animate_c import *
# %matplotlib qt
i=8
Animate_c(pos_for_different_l2[i],theta_for_different_l2[i],['blue','red'],[0.5,0.5],1000,100)

# %%
# %matplotlib inline
l_index=0
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.savefig("Plots/Varying_l/quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=0
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.xlim(8,11)
plt.ylim(11,14)
plt.savefig("Plots/Varying_l/zoomed_quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=3
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.ylabel('y')
plt.savefig("Plots/Varying_l/quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=3
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.xlim(8,12)
plt.ylim(3,7)
plt.savefig("Plots/Varying_l/zoomed_quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=-1
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.savefig("Plots/Varying_l/quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
# %matplotlib inline
l_index=-1
Quiver(pos_for_different_l2[l_index][-1], theta_for_different_l2[l_index][-1],['blue','red'])
plt.xlabel('x',fontsize=23)
plt.ylabel('y',fontsize=23)
plt.xlim(5,12)
plt.ylim(22,29)
plt.savefig("Plots/Varying_l/zoomed_quiver_l2_l="+str(l_list2[l_index])+".pdf" )
plt.show()

# %%
from Animate_c import *
# %matplotlib qt
i=-1
Animate_c(pos_for_different_l2[i],theta_for_different_l2[i],['blue','red'],[0.5,0.5],1000,100)

# %%
l_list2
# Out:
# array([0.6       , 0.86666667, 1.13333333, 1.4       , 1.66666667,
#        1.93333333, 2.2       , 2.46666667, 2.73333333, 3.        ])
